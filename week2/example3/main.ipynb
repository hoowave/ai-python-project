# %%
from application.service.plt_service import PltService

############### Applcation Main ###############
# 요구사항에 따라 절차순으로 작성하였습니다.
def main():
    pltService = PltService()
    pltService.step1()
    pltService.step2()
    pltService.step3()
    pltService.step4()
    pltService.step5()
    pltService.step6()
    pltService.step7()
    pltService.step8()

main()
# Out:
# KMeans 학습(k = 5)
# Silhouette Score (Train): 0.5510
# 학습 데이터 클러스터 시각화
# 테스트 데이터 클러스터 시각화
# 각 클러스터 특징 요약
#          Annual Income  Spending Score
# Cluster
# 0            55.825397       49.396825
# 1            26.550000       20.650000
# 2            25.684211       80.526316
# 3            87.823529       82.970588
# 4            90.625000       17.000000
