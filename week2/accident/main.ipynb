# %%
from env import Env
from service.plt_service import PltService

############### Applcation Main ###############
# 2024-12-05 기준 부산광역시 가해운전자 법규 위반별 사고 건수 데이터 사용
def main():
    env = Env()                         # 환경변수 불러오기
    pltService = PltService(env)        # 서비스객체 생성
    print("전체 합계를 계산하기 전 !!")
    pltService.run()                    # 전체 합계를 계산하기 전 테이블 출력
    pltService.process()                # 전체 합계 계산
    print("전체 합계를 계산한 후 !!")
    pltService.run()                    # 전체 합계 계산한 후 테이블 출력

main()
# Out:
# 전체 합계를 계산하기 전 !!
# 전체 합계를 계산한 후 !!
