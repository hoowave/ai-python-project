# %%
from domain.sales_analysis import SalesAnalysis
from service.plt_service import PltService

############### Applcation Main ###############
# .venv 파일은 제외하고 업로드 하였습니다!!
# .venv 파일은 제외하고 업로드 하였습니다!!
# .venv 파일은 제외하고 업로드 하였습니다!!
def main():
    analysis = SalesAnalysis()          # SalesAnalysis 객체 생성
    analysisDf = analysis.getDf()       # 객체 생성과 동시에 초기화했던 DataFrame 가져오기
    pltService = PltService(analysisDf) # PltService 생성 및 SalesAnalysis DataFrame 초기화
    pltService.run()                    # 그래프 생성

# 애플리케이션 진입점
main()
